# %% [markdown]
# # Adversarial Training for Flower Classification
#
# This notebook demonstrates how to perform **Adversarial Training** using the formula:
#
# $$\tilde{J}(\theta, x, y) = \alpha J(\theta, x, y) + (1 - \alpha) J(\theta, x + \epsilon \text{ sign}(\nabla_x J(\theta, x, y)))$$
#
# This approach makes the model more robust by training on a weighted mix of clean and adversarial examples.

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

print(f"TensorFlow version: {tf.__version__}")
# Out:
# 2026-06-09 06:16:38.002196: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780985798.194618      22 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780985798.259659      22 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780985798.708184      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780985798.708227      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780985798.708229      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780985798.708231      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow version: 2.19.0

# %% [markdown]
# ## 1. Data Preparation

# %% [markdown]
# Split

# %%
DATASET_PATH = '/kaggle/input/datasets/haidangg/flowerdataset/flower_photos'
TEST_SET_PATH = '/kaggle/input/datasets/haidangg/flowerdataset/flower_photos_test'

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_SET_PATH,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)

normalization_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))
# Out:
# Found 3090 files belonging to 5 classes.
# Using 2472 files for training.
# I0000 00:00:1780985825.942920      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780985825.948844      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 3090 files belonging to 5 classes.
# Using 618 files for validation.
# Found 580 files belonging to 5 classes.

# %% [markdown]
# ## 2. Model Definition

# %%
URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4" 
feature_extractor_layer = hub.KerasLayer(URL, input_shape=(224, 224, 3), trainable=True) 

# Tạo mô hình tuần tự
model = models.Sequential([
    feature_extractor_layer, # Khối MobileNetV2 đã được đóng băng
    layers.Dropout(0.5), # Regularization: ngẫu nhiên loại bỏ (đặt giá trị bằng 0) 50% số lượng neuron trong lớp đó, chống Overfitting
    layers.Dense(num_classes, activation='softmax') # Khối Head nhận đặc trưng và đưa ra dự đoán, softmax đảm bảo tổng xác suất đầu ra bằng 1
])

# Biên dịch mô hình
model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## 3. Adversarial Training Wrapper
#
# Here we implement the custom training step that follows the formula.

# %%
class AdversarialModel(models.Model):
    def __init__(self, base_model, epsilon=0.01, alpha=0.5, pgd_alpha=0.0025, pgd_steps=10):
        super(AdversarialModel, self).__init__()
        self.base_model = base_model
        
        # Tham số kết hợp Loss
        self.alpha = alpha
        
        # Tham số của PGD
        self.epsilon = epsilon
        self.pgd_alpha = pgd_alpha
        self.pgd_steps = pgd_steps
        
        self.loss_object = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)
        
        # Khởi tạo các bộ đếm Metrics chuyên biệt
        self.loss_total_metric = tf.keras.metrics.Mean(name="loss")
        self.acc_clean_metric = tf.keras.metrics.CategoricalAccuracy(name="std_acc")
        self.acc_adv_metric = tf.keras.metrics.CategoricalAccuracy(name="robust_acc")
        self.asr_metric = tf.keras.metrics.Mean(name="asr") # Attack Success Rate

    @property
    def metrics(self):
        return [self.loss_total_metric, self.acc_clean_metric, self.acc_adv_metric, self.asr_metric]

    def _calculate_asr(self, y_true, pred_clean, pred_adv):
        true_labels = tf.argmax(y_true, axis=1)
        clean_labels = tf.argmax(pred_clean, axis=1)
        adv_labels = tf.argmax(pred_adv, axis=1)
        
        clean_correct = tf.equal(clean_labels, true_labels)
        adv_incorrect = tf.not_equal(adv_labels, true_labels)
        successful_attacks = tf.logical_and(clean_correct, adv_incorrect)
        
        num_clean_correct = tf.reduce_sum(tf.cast(clean_correct, tf.float32))
        num_successful_attacks = tf.reduce_sum(tf.cast(successful_attacks, tf.float32))
        
        asr = tf.cond(num_clean_correct > 0,
                      lambda: num_successful_attacks / num_clean_correct,
                      lambda: 0.0)
        return asr

    def _generate_pgd_adversary(self, x, y):
        # 1. Khởi tạo ngẫu nhiên (Random Initialization) quanh điểm gốc x
        noise = tf.random.uniform(tf.shape(x), minval=-self.epsilon, maxval=self.epsilon)
        x_adv = x + noise
        x_adv = tf.clip_by_value(x_adv, 0.0, 1.0) # projection
        
        # 2. Vòng lặp tối ưu PGD
        for _ in range(self.pgd_steps):
            with tf.GradientTape() as tape_adv:
                tape_adv.watch(x_adv)
                prediction = self.base_model(x_adv, training=False)
                loss = self.loss_object(y, prediction)
                
            # Tính gradient của loss theo ảnh nhiễu hiện tại
            gradient = tape_adv.gradient(loss, x_adv)
            signed_grad = tf.sign(gradient)
            
            # Tiến 1 bước nhỏ pgd_alpha
            x_adv = x_adv + self.pgd_alpha * signed_grad
            
            # Phép chiếu (Projection) 1: Kẹp vào vùng epsilon của ảnh gốc x
            x_adv = tf.clip_by_value(x_adv, x - self.epsilon, x + self.epsilon)
            
            # Phép chiếu (Projection) 2: Kẹp vào không gian màu hợp lệ [0, 1]
            x_adv = tf.clip_by_value(x_adv, 0.0, 1.0)
            
        # Chỗ này là bước tạo ảnh nhiễu nên không tham gia vào backpropagation
        # stop đế cấm backpropagation dò lại các phép tính
        return tf.stop_gradient(x_adv)

    def train_step(self, data):
        x, y = data
        
        # 1. Chế tạo ảnh nhiễu PGD
        x_adv = self._generate_pgd_adversary(x, y)
        
        # 2. Dự đoán và Tính Loss tổng
        # GradientTape: tự động tính đạo hàm, được swur dụng để tính backpropagation
        with tf.GradientTape() as tape:
            pred_clean = self.base_model(x, training=True)
            pred_adv = self.base_model(x_adv, training=True)
            
            loss_clean = self.loss_object(y, pred_clean)
            loss_adv = self.loss_object(y, pred_adv)
            
            total_loss = self.alpha * loss_clean + (1.0 - self.alpha) * loss_adv
            
        # 3. Cập nhật trọng số Model
        gradients = tape.gradient(total_loss, self.base_model.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.base_model.trainable_variables))
        
        # 4. Cập nhật các thông số hiển thị
        asr = self._calculate_asr(y, pred_clean, pred_adv)
        
        self.loss_total_metric.update_state(total_loss)
        self.acc_clean_metric.update_state(y, pred_clean)
        self.acc_adv_metric.update_state(y, pred_adv)
        self.asr_metric.update_state(asr)
        
        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        x, y = data
        
        # 1. Chế tạo ảnh nhiễu PGD
        x_adv = self._generate_pgd_adversary(x, y)
        
        # 2. Dự đoán trên tập Validation (training=False)
        pred_clean = self.base_model(x, training=False)
        pred_adv = self.base_model(x_adv, training=False)
        
        loss_clean = self.loss_object(y, pred_clean)
        loss_adv = self.loss_object(y, pred_adv)
        total_loss = self.alpha * loss_clean + (1.0 - self.alpha) * loss_adv
        
        # 3. Cập nhật các thông số hiển thị cho tập Validation
        asr = self._calculate_asr(y, pred_clean, pred_adv)
        
        self.loss_total_metric.update_state(total_loss)
        self.acc_clean_metric.update_state(y, pred_clean)
        self.acc_adv_metric.update_state(y, pred_adv)
        self.asr_metric.update_state(asr)
        
        return {m.name: m.result() for m in self.metrics}

    def call(self, x):
        return self.base_model(x)

# Khởi tạo model với PGD steps = 10 và pgd_alpha thường bằng (epsilon / 4) hoặc (2.5 * epsilon / steps)
adv_training_model = AdversarialModel(
    base_model=model, # Giả sử 'model' là mạng neural gốc của bạn
    epsilon=0.01, 
    alpha=0.3, 
    pgd_alpha=0.0025, # Thêm mới
    pgd_steps=10      # Thêm mới
)

adv_training_model.compile(optimizer=Adam(learning_rate=1e-5))

# %% [markdown]
# ## 4. Training

# %%
# Dừng sớm nếu val_loss không giảm sau 7 epochs
early_stop = EarlyStopping(monitor='val_robust_acc', mode='max', patience=7, restore_best_weights=True)

# Giảm tốc độ học nếu mô hình bị chững lại
reduce_lr = ReduceLROnPlateau(monitor='val_robust_acc', mode='max', factor=0.5, patience=5)

EPOCHS = 200
history = adv_training_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/200
# I0000 00:00:1780985864.331350      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780985868.895228      71 service.cc:152] XLA service 0x796851445700 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780985868.895281      71 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780985868.895288      71 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780985869.146819      71 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 78/78 [==============================] - 210s 2s/step - loss: 3.8907 - std_acc: 0.2662 - robust_acc: 0.0053 - asr: 0.9870 - val_loss: 6.2059 - val_std_acc: 0.5291 - val_robust_acc: 0.0000e+00 - val_asr: 1.0000 - lr: 1.0000e-05
# Epoch 2/200
# 78/78 [==============================] - 144s 2s/step - loss: 3.9189 - std_acc: 0.4895 - robust_acc: 0.0061 - asr: 0.9872 - val_loss: 5.2748 - val_std_acc: 0.6893 - val_robust_acc: 0.0032 - val_asr: 0.9957 - lr: 1.0000e-05
# Epoch 3/200
# 78/78 [==============================] - 142s 2s/step - loss: 3.4939 - std_acc: 0.6108 - robust_acc: 0.0259 - asr: 0.9518 - val_loss: 4.7390 - val_std_acc: 0.7557 - val_robust_acc: 0.0210 - val_asr: 0.9740 - lr: 1.0000e-05
# Epoch 4/200
# 78/78 [==============================] - 143s 2s/step - loss: 3.0409 - std_acc: 0.6683 - robust_acc: 0.0485 - asr: 0.9269 - val_loss: 4.3002 - val_std_acc: 0.7913 - val_robust_acc: 0.0291 - val_asr: 0.9651 - lr: 1.0000e-05
# Epoch 5/200
# 78/78 [==============================] - 142s 2s/step - loss: 2.7529 - std_acc: 0.7055 - robust_acc: 0.0583 - asr: 0.9197 - val_loss: 3.8957 - val_std_acc: 0.8236 - val_robust_acc: 0.0356 - val_asr: 0.9584 - lr: 1.0000e-05
# Epoch 6/200
# 78/78 [==============================] - 143s 2s/step - loss: 2.5024 - std_acc: 0.7334 - robust_acc: 0.0635 - asr: 0.9122 - val_loss: 3.5101 - val_std_acc: 0.8333 - val_robust_acc: 0.0388 - val_asr: 0.9542 - lr: 1.0000e-05
# Epoch 7/200
# 78/78 [==============================] - 142s 2s/step - loss: 2.3091 - std_acc: 0.7464 - robust_acc: 0.0688 - asr: 0.9075 - val_loss: 3.2223 - val_std_acc: 0.8447 - val_robust_acc: 0.0388 - val_asr: 0.9554 - lr: 1.0000e-05
# Epoch 8/200
# 78/78 [==============================] - 142s 2s/step - loss: 2.1859 - std_acc: 0.7581 - robust_acc: 0.0680 - asr: 0.9123 - val_loss: 2.9544 - val_std_acc: 0.8528 - val_robust_acc: 0.0372 - val_asr: 0.9575 - lr: 1.0000e-05
# Epoch 9/200
# 78/78 [==============================] - 142s 2s/step - loss: 2.0546 - std_acc: 0.7654 - robust_acc: 0.0752 - asr: 0.8982 - val_loss: 2.7291 - val_std_acc: 0.8495 - val_robust_acc: 0.0372 - val_asr: 0.9581 - lr: 1.0000e-05
# Epoch 10/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.9551 - std_acc: 0.7803 - robust_acc: 0.0765 - asr: 0.9019 - val_loss: 2.5181 - val_std_acc: 0.8592 - val_robust_acc: 0.0405 - val_asr: 0.9540 - lr: 1.0000e-05
# Epoch 11/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.8590 - std_acc: 0.7864 - robust_acc: 0.0955 - asr: 0.8807 - val_loss: 2.3781 - val_std_acc: 0.8528 - val_robust_acc: 0.0405 - val_asr: 0.9557 - lr: 1.0000e-05
# Epoch 12/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.7861 - std_acc: 0.7917 - robust_acc: 0.1003 - asr: 0.8681 - val_loss: 2.2440 - val_std_acc: 0.8528 - val_robust_acc: 0.0421 - val_asr: 0.9532 - lr: 1.0000e-05
# Epoch 13/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.7395 - std_acc: 0.7941 - robust_acc: 0.1080 - asr: 0.8627 - val_loss: 2.1064 - val_std_acc: 0.8544 - val_robust_acc: 0.0405 - val_asr: 0.9472 - lr: 1.0000e-05
# Epoch 14/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.6739 - std_acc: 0.7973 - robust_acc: 0.1161 - asr: 0.8520 - val_loss: 2.0297 - val_std_acc: 0.8576 - val_robust_acc: 0.0405 - val_asr: 0.9554 - lr: 1.0000e-05
# Epoch 15/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.6418 - std_acc: 0.7771 - robust_acc: 0.1197 - asr: 0.8446 - val_loss: 1.9415 - val_std_acc: 0.8625 - val_robust_acc: 0.0405 - val_asr: 0.9478 - lr: 1.0000e-05
# Epoch 16/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.6165 - std_acc: 0.7965 - robust_acc: 0.1392 - asr: 0.8273 - val_loss: 1.8858 - val_std_acc: 0.8625 - val_robust_acc: 0.0437 - val_asr: 0.9502 - lr: 1.0000e-05
# Epoch 17/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.5934 - std_acc: 0.7973 - robust_acc: 0.1489 - asr: 0.8112 - val_loss: 1.8429 - val_std_acc: 0.8657 - val_robust_acc: 0.0421 - val_asr: 0.9538 - lr: 1.0000e-05
# Epoch 18/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.5606 - std_acc: 0.8087 - robust_acc: 0.1590 - asr: 0.8028 - val_loss: 1.7836 - val_std_acc: 0.8625 - val_robust_acc: 0.0469 - val_asr: 0.9447 - lr: 1.0000e-05
# Epoch 19/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.5464 - std_acc: 0.7981 - robust_acc: 0.1687 - asr: 0.7936 - val_loss: 1.7611 - val_std_acc: 0.8641 - val_robust_acc: 0.0534 - val_asr: 0.9403 - lr: 1.0000e-05
# Epoch 20/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.5239 - std_acc: 0.7994 - robust_acc: 0.1889 - asr: 0.7647 - val_loss: 1.7294 - val_std_acc: 0.8641 - val_robust_acc: 0.0583 - val_asr: 0.9325 - lr: 1.0000e-05
# Epoch 21/200
# 78/78 [==============================] - 143s 2s/step - loss: 1.5136 - std_acc: 0.8018 - robust_acc: 0.1950 - asr: 0.7558 - val_loss: 1.7082 - val_std_acc: 0.8641 - val_robust_acc: 0.0615 - val_asr: 0.9315 - lr: 1.0000e-05
# Epoch 22/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.5017 - std_acc: 0.8087 - robust_acc: 0.2132 - asr: 0.7351 - val_loss: 1.6894 - val_std_acc: 0.8706 - val_robust_acc: 0.0744 - val_asr: 0.9171 - lr: 1.0000e-05
# Epoch 23/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.4869 - std_acc: 0.8220 - robust_acc: 0.2116 - asr: 0.7459 - val_loss: 1.6739 - val_std_acc: 0.8706 - val_robust_acc: 0.0793 - val_asr: 0.9085 - lr: 1.0000e-05
# Epoch 24/200
# 78/78 [==============================] - 143s 2s/step - loss: 1.4788 - std_acc: 0.8123 - robust_acc: 0.2225 - asr: 0.7277 - val_loss: 1.6488 - val_std_acc: 0.8689 - val_robust_acc: 0.0955 - val_asr: 0.8891 - lr: 1.0000e-05
# Epoch 25/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.4621 - std_acc: 0.8159 - robust_acc: 0.2358 - asr: 0.7137 - val_loss: 1.6418 - val_std_acc: 0.8657 - val_robust_acc: 0.1068 - val_asr: 0.8818 - lr: 1.0000e-05
# Epoch 26/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.4580 - std_acc: 0.8289 - robust_acc: 0.2520 - asr: 0.7017 - val_loss: 1.6244 - val_std_acc: 0.8657 - val_robust_acc: 0.1117 - val_asr: 0.8758 - lr: 1.0000e-05
# Epoch 27/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.4429 - std_acc: 0.8180 - robust_acc: 0.2625 - asr: 0.6794 - val_loss: 1.6035 - val_std_acc: 0.8657 - val_robust_acc: 0.1311 - val_asr: 0.8463 - lr: 1.0000e-05
# Epoch 28/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.4331 - std_acc: 0.8192 - robust_acc: 0.2658 - asr: 0.6737 - val_loss: 1.5826 - val_std_acc: 0.8706 - val_robust_acc: 0.1359 - val_asr: 0.8433 - lr: 1.0000e-05
# Epoch 29/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.4147 - std_acc: 0.8309 - robust_acc: 0.2933 - asr: 0.6480 - val_loss: 1.5697 - val_std_acc: 0.8738 - val_robust_acc: 0.1472 - val_asr: 0.8264 - lr: 1.0000e-05
# Epoch 30/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.4009 - std_acc: 0.8309 - robust_acc: 0.2977 - asr: 0.6457 - val_loss: 1.5499 - val_std_acc: 0.8738 - val_robust_acc: 0.1570 - val_asr: 0.8135 - lr: 1.0000e-05
# Epoch 31/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.3925 - std_acc: 0.8301 - robust_acc: 0.2969 - asr: 0.6404 - val_loss: 1.5407 - val_std_acc: 0.8738 - val_robust_acc: 0.1683 - val_asr: 0.8103 - lr: 1.0000e-05
# Epoch 32/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.3821 - std_acc: 0.8362 - robust_acc: 0.3147 - asr: 0.6265 - val_loss: 1.5440 - val_std_acc: 0.8722 - val_robust_acc: 0.1893 - val_asr: 0.7851 - lr: 1.0000e-05
# Epoch 33/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.3645 - std_acc: 0.8333 - robust_acc: 0.3220 - asr: 0.6168 - val_loss: 1.5103 - val_std_acc: 0.8754 - val_robust_acc: 0.1942 - val_asr: 0.7757 - lr: 1.0000e-05
# Epoch 34/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.3603 - std_acc: 0.8382 - robust_acc: 0.3309 - asr: 0.6051 - val_loss: 1.5080 - val_std_acc: 0.8754 - val_robust_acc: 0.2006 - val_asr: 0.7733 - lr: 1.0000e-05
# Epoch 35/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.3427 - std_acc: 0.8386 - robust_acc: 0.3515 - asr: 0.5833 - val_loss: 1.4938 - val_std_acc: 0.8803 - val_robust_acc: 0.2184 - val_asr: 0.7596 - lr: 1.0000e-05
# Epoch 36/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.3179 - std_acc: 0.8447 - robust_acc: 0.3548 - asr: 0.5830 - val_loss: 1.4776 - val_std_acc: 0.8819 - val_robust_acc: 0.2298 - val_asr: 0.7391 - lr: 1.0000e-05
# Epoch 37/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.3165 - std_acc: 0.8451 - robust_acc: 0.3714 - asr: 0.5579 - val_loss: 1.4538 - val_std_acc: 0.8851 - val_robust_acc: 0.2443 - val_asr: 0.7175 - lr: 1.0000e-05
# Epoch 38/200
# 78/78 [==============================] - 143s 2s/step - loss: 1.2924 - std_acc: 0.8483 - robust_acc: 0.3790 - asr: 0.5576 - val_loss: 1.4613 - val_std_acc: 0.8803 - val_robust_acc: 0.2540 - val_asr: 0.7074 - lr: 1.0000e-05
# Epoch 39/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.2845 - std_acc: 0.8439 - robust_acc: 0.3896 - asr: 0.5419 - val_loss: 1.4290 - val_std_acc: 0.8867 - val_robust_acc: 0.2589 - val_asr: 0.7006 - lr: 1.0000e-05
# Epoch 40/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.2618 - std_acc: 0.8612 - robust_acc: 0.3993 - asr: 0.5416 - val_loss: 1.4182 - val_std_acc: 0.8883 - val_robust_acc: 0.2735 - val_asr: 0.6887 - lr: 1.0000e-05
# Epoch 41/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.2516 - std_acc: 0.8523 - robust_acc: 0.4110 - asr: 0.5209 - val_loss: 1.4227 - val_std_acc: 0.8900 - val_robust_acc: 0.2767 - val_asr: 0.6949 - lr: 1.0000e-05
# Epoch 42/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.2533 - std_acc: 0.8503 - robust_acc: 0.4122 - asr: 0.5143 - val_loss: 1.3948 - val_std_acc: 0.8916 - val_robust_acc: 0.2913 - val_asr: 0.6780 - lr: 1.0000e-05
# Epoch 43/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.2301 - std_acc: 0.8536 - robust_acc: 0.4248 - asr: 0.5040 - val_loss: 1.3709 - val_std_acc: 0.8900 - val_robust_acc: 0.3010 - val_asr: 0.6564 - lr: 1.0000e-05
# Epoch 44/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.2189 - std_acc: 0.8645 - robust_acc: 0.4409 - asr: 0.4961 - val_loss: 1.3663 - val_std_acc: 0.8948 - val_robust_acc: 0.3172 - val_asr: 0.6421 - lr: 1.0000e-05
# Epoch 45/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.2042 - std_acc: 0.8604 - robust_acc: 0.4462 - asr: 0.4835 - val_loss: 1.3598 - val_std_acc: 0.8916 - val_robust_acc: 0.3236 - val_asr: 0.6389 - lr: 1.0000e-05
# Epoch 46/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.1855 - std_acc: 0.8556 - robust_acc: 0.4511 - asr: 0.4782 - val_loss: 1.3472 - val_std_acc: 0.8916 - val_robust_acc: 0.3398 - val_asr: 0.6212 - lr: 1.0000e-05
# Epoch 47/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.1702 - std_acc: 0.8649 - robust_acc: 0.4664 - asr: 0.4618 - val_loss: 1.3287 - val_std_acc: 0.8867 - val_robust_acc: 0.3495 - val_asr: 0.5994 - lr: 1.0000e-05
# Epoch 48/200
# 78/78 [==============================] - 143s 2s/step - loss: 1.1584 - std_acc: 0.8681 - robust_acc: 0.4786 - asr: 0.4557 - val_loss: 1.3249 - val_std_acc: 0.8916 - val_robust_acc: 0.3625 - val_asr: 0.5942 - lr: 1.0000e-05
# Epoch 49/200
# 78/78 [==============================] - 143s 2s/step - loss: 1.1482 - std_acc: 0.8677 - robust_acc: 0.4790 - asr: 0.4501 - val_loss: 1.2941 - val_std_acc: 0.8900 - val_robust_acc: 0.3770 - val_asr: 0.5789 - lr: 1.0000e-05
# Epoch 50/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.1255 - std_acc: 0.8730 - robust_acc: 0.4923 - asr: 0.4344 - val_loss: 1.2924 - val_std_acc: 0.8883 - val_robust_acc: 0.3738 - val_asr: 0.5906 - lr: 1.0000e-05
# Epoch 51/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.1100 - std_acc: 0.8734 - robust_acc: 0.4992 - asr: 0.4292 - val_loss: 1.2765 - val_std_acc: 0.8916 - val_robust_acc: 0.3835 - val_asr: 0.5656 - lr: 1.0000e-05
# Epoch 52/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.0955 - std_acc: 0.8770 - robust_acc: 0.5032 - asr: 0.4297 - val_loss: 1.2662 - val_std_acc: 0.8883 - val_robust_acc: 0.3932 - val_asr: 0.5619 - lr: 1.0000e-05
# Epoch 53/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.0802 - std_acc: 0.8799 - robust_acc: 0.5283 - asr: 0.4021 - val_loss: 1.2527 - val_std_acc: 0.8916 - val_robust_acc: 0.4078 - val_asr: 0.5396 - lr: 1.0000e-05
# Epoch 54/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.0721 - std_acc: 0.8823 - robust_acc: 0.5162 - asr: 0.4142 - val_loss: 1.2411 - val_std_acc: 0.8948 - val_robust_acc: 0.4126 - val_asr: 0.5182 - lr: 1.0000e-05
# Epoch 55/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.0543 - std_acc: 0.8863 - robust_acc: 0.5405 - asr: 0.3954 - val_loss: 1.2375 - val_std_acc: 0.8932 - val_robust_acc: 0.4207 - val_asr: 0.5423 - lr: 1.0000e-05
# Epoch 56/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.0526 - std_acc: 0.8896 - robust_acc: 0.5328 - asr: 0.4019 - val_loss: 1.2050 - val_std_acc: 0.8932 - val_robust_acc: 0.4337 - val_asr: 0.5110 - lr: 1.0000e-05
# Epoch 57/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.0392 - std_acc: 0.8863 - robust_acc: 0.5465 - asr: 0.3890 - val_loss: 1.2103 - val_std_acc: 0.8964 - val_robust_acc: 0.4434 - val_asr: 0.5086 - lr: 1.0000e-05
# Epoch 58/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.0143 - std_acc: 0.8908 - robust_acc: 0.5530 - asr: 0.3818 - val_loss: 1.1926 - val_std_acc: 0.8981 - val_robust_acc: 0.4417 - val_asr: 0.5039 - lr: 1.0000e-05
# Epoch 59/200
# 78/78 [==============================] - 142s 2s/step - loss: 1.0073 - std_acc: 0.8932 - robust_acc: 0.5651 - asr: 0.3690 - val_loss: 1.1762 - val_std_acc: 0.8964 - val_robust_acc: 0.4563 - val_asr: 0.4884 - lr: 1.0000e-05
# Epoch 60/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9994 - std_acc: 0.8956 - robust_acc: 0.5724 - asr: 0.3596 - val_loss: 1.1841 - val_std_acc: 0.8981 - val_robust_acc: 0.4612 - val_asr: 0.4917 - lr: 1.0000e-05
# Epoch 61/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9851 - std_acc: 0.8981 - robust_acc: 0.5858 - asr: 0.3458 - val_loss: 1.1710 - val_std_acc: 0.8997 - val_robust_acc: 0.4709 - val_asr: 0.4766 - lr: 1.0000e-05
# Epoch 62/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9776 - std_acc: 0.8944 - robust_acc: 0.5943 - asr: 0.3377 - val_loss: 1.1699 - val_std_acc: 0.8981 - val_robust_acc: 0.4757 - val_asr: 0.4750 - lr: 1.0000e-05
# Epoch 63/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9712 - std_acc: 0.9017 - robust_acc: 0.5930 - asr: 0.3434 - val_loss: 1.1489 - val_std_acc: 0.8964 - val_robust_acc: 0.4871 - val_asr: 0.4647 - lr: 1.0000e-05
# Epoch 64/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9704 - std_acc: 0.9021 - robust_acc: 0.5959 - asr: 0.3419 - val_loss: 1.1396 - val_std_acc: 0.8997 - val_robust_acc: 0.4984 - val_asr: 0.4504 - lr: 1.0000e-05
# Epoch 65/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9539 - std_acc: 0.9025 - robust_acc: 0.6011 - asr: 0.3367 - val_loss: 1.1306 - val_std_acc: 0.8997 - val_robust_acc: 0.5016 - val_asr: 0.4429 - lr: 1.0000e-05
# Epoch 66/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9453 - std_acc: 0.9013 - robust_acc: 0.6092 - asr: 0.3240 - val_loss: 1.1192 - val_std_acc: 0.9029 - val_robust_acc: 0.5097 - val_asr: 0.4278 - lr: 1.0000e-05
# Epoch 67/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9419 - std_acc: 0.9009 - robust_acc: 0.6189 - asr: 0.3101 - val_loss: 1.1052 - val_std_acc: 0.9045 - val_robust_acc: 0.5113 - val_asr: 0.4259 - lr: 1.0000e-05
# Epoch 68/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9216 - std_acc: 0.9118 - robust_acc: 0.6319 - asr: 0.3078 - val_loss: 1.1034 - val_std_acc: 0.9013 - val_robust_acc: 0.5146 - val_asr: 0.4318 - lr: 1.0000e-05
# Epoch 69/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9156 - std_acc: 0.9138 - robust_acc: 0.6351 - asr: 0.3067 - val_loss: 1.0956 - val_std_acc: 0.9029 - val_robust_acc: 0.5178 - val_asr: 0.4190 - lr: 1.0000e-05
# Epoch 70/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9077 - std_acc: 0.9159 - robust_acc: 0.6262 - asr: 0.3173 - val_loss: 1.1043 - val_std_acc: 0.9045 - val_robust_acc: 0.5324 - val_asr: 0.4088 - lr: 1.0000e-05
# Epoch 71/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.9043 - std_acc: 0.9094 - robust_acc: 0.6468 - asr: 0.2900 - val_loss: 1.1037 - val_std_acc: 0.9061 - val_robust_acc: 0.5324 - val_asr: 0.4156 - lr: 1.0000e-05
# Epoch 72/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.8909 - std_acc: 0.9142 - robust_acc: 0.6440 - asr: 0.2975 - val_loss: 1.0751 - val_std_acc: 0.9061 - val_robust_acc: 0.5307 - val_asr: 0.4129 - lr: 1.0000e-05
# Epoch 73/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.8795 - std_acc: 0.9159 - robust_acc: 0.6578 - asr: 0.2818 - val_loss: 1.0705 - val_std_acc: 0.9061 - val_robust_acc: 0.5324 - val_asr: 0.4033 - lr: 1.0000e-05
# Epoch 74/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.8713 - std_acc: 0.9260 - robust_acc: 0.6630 - asr: 0.2846 - val_loss: 1.0649 - val_std_acc: 0.9078 - val_robust_acc: 0.5469 - val_asr: 0.3992 - lr: 1.0000e-05
# Epoch 75/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.8649 - std_acc: 0.9163 - robust_acc: 0.6570 - asr: 0.2835 - val_loss: 1.0627 - val_std_acc: 0.9094 - val_robust_acc: 0.5469 - val_asr: 0.3959 - lr: 1.0000e-05
# Epoch 76/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.8600 - std_acc: 0.9227 - robust_acc: 0.6606 - asr: 0.2822 - val_loss: 1.0632 - val_std_acc: 0.9061 - val_robust_acc: 0.5502 - val_asr: 0.3920 - lr: 1.0000e-05
# Epoch 77/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.8614 - std_acc: 0.9203 - robust_acc: 0.6768 - asr: 0.2663 - val_loss: 1.0538 - val_std_acc: 0.9142 - val_robust_acc: 0.5502 - val_asr: 0.3976 - lr: 1.0000e-05
# Epoch 78/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.8417 - std_acc: 0.9280 - robust_acc: 0.6752 - asr: 0.2738 - val_loss: 1.0461 - val_std_acc: 0.9159 - val_robust_acc: 0.5534 - val_asr: 0.3995 - lr: 1.0000e-05
# Epoch 79/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.8309 - std_acc: 0.9304 - robust_acc: 0.6909 - asr: 0.2594 - val_loss: 1.0422 - val_std_acc: 0.9175 - val_robust_acc: 0.5583 - val_asr: 0.4001 - lr: 1.0000e-05
# Epoch 80/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.8221 - std_acc: 0.9333 - robust_acc: 0.6982 - asr: 0.2520 - val_loss: 1.0488 - val_std_acc: 0.9175 - val_robust_acc: 0.5534 - val_asr: 0.4099 - lr: 1.0000e-05
# Epoch 81/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.8124 - std_acc: 0.9324 - robust_acc: 0.7043 - asr: 0.2459 - val_loss: 1.0377 - val_std_acc: 0.9159 - val_robust_acc: 0.5680 - val_asr: 0.3793 - lr: 1.0000e-05
# Epoch 82/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.8174 - std_acc: 0.9345 - robust_acc: 0.6994 - asr: 0.2531 - val_loss: 1.0248 - val_std_acc: 0.9159 - val_robust_acc: 0.5744 - val_asr: 0.3835 - lr: 1.0000e-05
# Epoch 83/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.8094 - std_acc: 0.9300 - robust_acc: 0.7059 - asr: 0.2444 - val_loss: 1.0235 - val_std_acc: 0.9191 - val_robust_acc: 0.5761 - val_asr: 0.3771 - lr: 1.0000e-05
# Epoch 84/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7963 - std_acc: 0.9381 - robust_acc: 0.7160 - asr: 0.2368 - val_loss: 1.0132 - val_std_acc: 0.9191 - val_robust_acc: 0.5809 - val_asr: 0.3578 - lr: 1.0000e-05
# Epoch 85/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7985 - std_acc: 0.9353 - robust_acc: 0.7075 - asr: 0.2427 - val_loss: 1.0079 - val_std_acc: 0.9207 - val_robust_acc: 0.5809 - val_asr: 0.3665 - lr: 1.0000e-05
# Epoch 86/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7953 - std_acc: 0.9413 - robust_acc: 0.7184 - asr: 0.2412 - val_loss: 1.0090 - val_std_acc: 0.9207 - val_robust_acc: 0.5809 - val_asr: 0.3690 - lr: 1.0000e-05
# Epoch 87/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7772 - std_acc: 0.9474 - robust_acc: 0.7257 - asr: 0.2352 - val_loss: 1.0183 - val_std_acc: 0.9207 - val_robust_acc: 0.5793 - val_asr: 0.3727 - lr: 1.0000e-05
# Epoch 88/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7735 - std_acc: 0.9401 - robust_acc: 0.7237 - asr: 0.2295 - val_loss: 1.0301 - val_std_acc: 0.9191 - val_robust_acc: 0.5744 - val_asr: 0.3892 - lr: 1.0000e-05
# Epoch 89/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.7644 - std_acc: 0.9498 - robust_acc: 0.7330 - asr: 0.2282 - val_loss: 1.0086 - val_std_acc: 0.9207 - val_robust_acc: 0.5890 - val_asr: 0.3735 - lr: 1.0000e-05
# Epoch 90/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7594 - std_acc: 0.9474 - robust_acc: 0.7395 - asr: 0.2204 - val_loss: 1.0009 - val_std_acc: 0.9191 - val_robust_acc: 0.5906 - val_asr: 0.3649 - lr: 1.0000e-05
# Epoch 91/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7601 - std_acc: 0.9478 - robust_acc: 0.7431 - asr: 0.2187 - val_loss: 0.9831 - val_std_acc: 0.9239 - val_robust_acc: 0.5939 - val_asr: 0.3474 - lr: 1.0000e-05
# Epoch 92/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.7554 - std_acc: 0.9454 - robust_acc: 0.7403 - asr: 0.2171 - val_loss: 0.9999 - val_std_acc: 0.9272 - val_robust_acc: 0.5858 - val_asr: 0.3742 - lr: 1.0000e-05
# Epoch 93/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7443 - std_acc: 0.9506 - robust_acc: 0.7443 - asr: 0.2187 - val_loss: 1.0041 - val_std_acc: 0.9223 - val_robust_acc: 0.5939 - val_asr: 0.3691 - lr: 1.0000e-05
# Epoch 94/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7373 - std_acc: 0.9551 - robust_acc: 0.7549 - asr: 0.2115 - val_loss: 0.9853 - val_std_acc: 0.9272 - val_robust_acc: 0.5922 - val_asr: 0.3624 - lr: 1.0000e-05
# Epoch 95/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7294 - std_acc: 0.9527 - robust_acc: 0.7573 - asr: 0.2054 - val_loss: 0.9859 - val_std_acc: 0.9223 - val_robust_acc: 0.6003 - val_asr: 0.3480 - lr: 1.0000e-05
# Epoch 96/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.7261 - std_acc: 0.9527 - robust_acc: 0.7646 - asr: 0.1965 - val_loss: 0.9831 - val_std_acc: 0.9288 - val_robust_acc: 0.5955 - val_asr: 0.3597 - lr: 1.0000e-05
# Epoch 97/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7215 - std_acc: 0.9531 - robust_acc: 0.7747 - asr: 0.1900 - val_loss: 0.9799 - val_std_acc: 0.9304 - val_robust_acc: 0.5971 - val_asr: 0.3641 - lr: 1.0000e-05
# Epoch 98/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7185 - std_acc: 0.9555 - robust_acc: 0.7735 - asr: 0.1899 - val_loss: 0.9681 - val_std_acc: 0.9288 - val_robust_acc: 0.6003 - val_asr: 0.3447 - lr: 1.0000e-05
# Epoch 99/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.7003 - std_acc: 0.9604 - robust_acc: 0.7836 - asr: 0.1821 - val_loss: 0.9637 - val_std_acc: 0.9320 - val_robust_acc: 0.5987 - val_asr: 0.3533 - lr: 1.0000e-05
# Epoch 100/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6986 - std_acc: 0.9628 - robust_acc: 0.7900 - asr: 0.1800 - val_loss: 0.9734 - val_std_acc: 0.9369 - val_robust_acc: 0.6052 - val_asr: 0.3562 - lr: 1.0000e-05
# Epoch 101/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6915 - std_acc: 0.9660 - robust_acc: 0.7981 - asr: 0.1733 - val_loss: 0.9711 - val_std_acc: 0.9320 - val_robust_acc: 0.6036 - val_asr: 0.3585 - lr: 1.0000e-05
# Epoch 102/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6912 - std_acc: 0.9587 - robust_acc: 0.7961 - asr: 0.1715 - val_loss: 0.9733 - val_std_acc: 0.9337 - val_robust_acc: 0.6068 - val_asr: 0.3510 - lr: 1.0000e-05
# Epoch 103/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6831 - std_acc: 0.9604 - robust_acc: 0.7994 - asr: 0.1664 - val_loss: 0.9629 - val_std_acc: 0.9337 - val_robust_acc: 0.6036 - val_asr: 0.3489 - lr: 1.0000e-05
# Epoch 104/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6721 - std_acc: 0.9672 - robust_acc: 0.8046 - asr: 0.1695 - val_loss: 0.9797 - val_std_acc: 0.9320 - val_robust_acc: 0.6117 - val_asr: 0.3443 - lr: 1.0000e-05
# Epoch 105/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6665 - std_acc: 0.9632 - robust_acc: 0.8103 - asr: 0.1578 - val_loss: 0.9816 - val_std_acc: 0.9320 - val_robust_acc: 0.6100 - val_asr: 0.3531 - lr: 1.0000e-05
# Epoch 106/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.6673 - std_acc: 0.9648 - robust_acc: 0.8151 - asr: 0.1575 - val_loss: 0.9687 - val_std_acc: 0.9337 - val_robust_acc: 0.6100 - val_asr: 0.3330 - lr: 1.0000e-05
# Epoch 107/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6549 - std_acc: 0.9725 - robust_acc: 0.8180 - asr: 0.1592 - val_loss: 0.9787 - val_std_acc: 0.9353 - val_robust_acc: 0.6149 - val_asr: 0.3512 - lr: 1.0000e-05
# Epoch 108/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6589 - std_acc: 0.9684 - robust_acc: 0.8184 - asr: 0.1559 - val_loss: 0.9800 - val_std_acc: 0.9337 - val_robust_acc: 0.6165 - val_asr: 0.3439 - lr: 1.0000e-05
# Epoch 109/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.6467 - std_acc: 0.9701 - robust_acc: 0.8329 - asr: 0.1404 - val_loss: 0.9745 - val_std_acc: 0.9353 - val_robust_acc: 0.6117 - val_asr: 0.3531 - lr: 1.0000e-05
# Epoch 110/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.6435 - std_acc: 0.9737 - robust_acc: 0.8228 - asr: 0.1559 - val_loss: 0.9658 - val_std_acc: 0.9353 - val_robust_acc: 0.6100 - val_asr: 0.3554 - lr: 1.0000e-05
# Epoch 111/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.6336 - std_acc: 0.9790 - robust_acc: 0.8398 - asr: 0.1436 - val_loss: 0.9658 - val_std_acc: 0.9369 - val_robust_acc: 0.6117 - val_asr: 0.3345 - lr: 1.0000e-05
# Epoch 112/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6270 - std_acc: 0.9761 - robust_acc: 0.8414 - asr: 0.1376 - val_loss: 0.9631 - val_std_acc: 0.9353 - val_robust_acc: 0.6100 - val_asr: 0.3470 - lr: 1.0000e-05
# Epoch 113/200
# 78/78 [==============================] - 142s 2s/step - loss: 0.6318 - std_acc: 0.9757 - robust_acc: 0.8337 - asr: 0.1452 - val_loss: 0.9629 - val_std_acc: 0.9353 - val_robust_acc: 0.6117 - val_asr: 0.3461 - lr: 1.0000e-05
# Epoch 114/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6242 - std_acc: 0.9745 - robust_acc: 0.8487 - asr: 0.1308 - val_loss: 0.9636 - val_std_acc: 0.9353 - val_robust_acc: 0.6149 - val_asr: 0.3437 - lr: 5.0000e-06
# Epoch 115/200
# 78/78 [==============================] - 143s 2s/step - loss: 0.6168 - std_acc: 0.9765 - robust_acc: 0.8463 - asr: 0.1377 - val_loss: 0.9709 - val_std_acc: 0.9337 - val_robust_acc: 0.6133 - val_asr: 0.3418 - lr: 5.0000e-06

# %% [markdown]
# ## 5. Training Monitoring

# %%
def plot_training_history(history):
    # Lấy dictionary chứa lịch sử các thông số
    h = history.history
    
    # Lấy số lượng epoch thực tế (đề phòng EarlyStopping dừng sớm)
    epochs = range(1, len(h['loss']) + 1)
    
    # Tạo một khung hình lớn chứa 4 biểu đồ nhỏ (2 hàng, 2 cột)
    plt.figure(figsize=(16, 10))
    plt.suptitle('BÁO CÁO QUÁ TRÌNH HUẤN LUYỆN ĐỐI KHÁNG', fontsize=16, fontweight='bold', y=1.02)

    # ---------------------------------------------
    # BIỂU ĐỒ 1: TỔNG SAI SỐ (TOTAL LOSS) - CÀNG THẤP CÀNG TỐT
    # ---------------------------------------------
    plt.subplot(2, 2, 1)
    plt.plot(epochs, h['loss'], 'b-', linewidth=2, label='Train Loss')
    if 'val_loss' in h:
        plt.plot(epochs, h['val_loss'], 'r--', linewidth=2, label='Validation Loss')
    plt.title('1. Biến thiên Tổng Sai Số (Loss)')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()

    # ---------------------------------------------
    # BIỂU ĐỒ 2: STANDARD ACCURACY - CÀNG CAO CÀNG TỐT
    # ---------------------------------------------
    plt.subplot(2, 2, 2)
    plt.plot(epochs, h['std_acc'], 'b-', linewidth=2, label='Train Std Acc')
    if 'val_std_acc' in h:
        plt.plot(epochs, h['val_std_acc'], 'r--', linewidth=2, label='Validation Std Acc')
    plt.title('2. Độ chính xác trên Ảnh Sạch (Standard Acc)')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1.05])
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()

    # ---------------------------------------------
    # BIỂU ĐỒ 3: ROBUST ACCURACY - CÀNG CAO CÀNG TỐT
    # ---------------------------------------------
    plt.subplot(2, 2, 3)
    plt.plot(epochs, h['robust_acc'], 'b-', linewidth=2, label='Train Robust Acc')
    if 'val_robust_acc' in h:
        plt.plot(epochs, h['val_robust_acc'], 'r--', linewidth=2, label='Validation Robust Acc')
    plt.title('3. Sức đề kháng với Ảnh Nhiễu (Robust Acc)')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1.05])
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()

    # ---------------------------------------------
    # BIỂU ĐỒ 4: ATTACK SUCCESS RATE (ASR) - CÀNG THẤP CÀNG TỐT
    # ---------------------------------------------
    plt.subplot(2, 2, 4)
    plt.plot(epochs, h['asr'], 'b-', linewidth=2, label='Train ASR')
    if 'val_asr' in h:
        plt.plot(epochs, h['val_asr'], 'r--', linewidth=2, label='Validation ASR')
    plt.title('4. Tỷ lệ Bị Đánh Lừa Thành Công (ASR)')
    plt.xlabel('Epochs')
    plt.ylabel('Attack Success Rate')
    plt.ylim([-0.05, 1.05])
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()

    # Tối ưu khoảng cách giữa các biểu đồ
    plt.tight_layout()
    plt.show()

# Gọi hàm vẽ bằng cách truyền biến history vào
plot_training_history(history)

# %% [markdown]
# ## 6. Evaluation

# %%
def evaluate_robustness(model, dataset, class_names, epsilon=0.01, num_visualize=3):
    """
    Hàm đánh giá độ bền vững của mô hình và trực quan hóa kết quả.
    
    Args:
        model: Mô hình Keras cần đánh giá.
        dataset: Tập dữ liệu (VD: val_ds).
        class_names: Danh sách tên các nhãn (VD: ['Hoa cúc', 'Hoa hồng', ...]).
        epsilon: Biên độ nhiễu.
        num_visualize: Số lượng ví dụ muốn hiển thị ra biểu đồ.
    """
    clean_acc = tf.keras.metrics.CategoricalAccuracy()
    adv_acc = tf.keras.metrics.CategoricalAccuracy()
    
    total_correct_clean = 0
    successful_attacks = 0
    
    # Biến lưu trữ dữ liệu để vẽ biểu đồ
    viz_clean_imgs, viz_adv_imgs, viz_noises = [], [], []
    viz_clean_preds, viz_adv_preds, viz_true_labels = [], [], []

    for x, y in dataset:
        # Nhớ để training=False để Dropout/BatchNorm không hoạt động sai
        clean_preds = model(x, training=False) 
        clean_acc.update_state(y, clean_preds)
        
        with tf.GradientTape() as tape:
            tape.watch(x)
            preds = model(x, training=False)
            loss = tf.keras.losses.CategoricalCrossentropy()(y, preds)
        
        grad = tape.gradient(loss, x)
        signed_grad = tf.sign(grad)
        x_adv = x + epsilon * signed_grad
        x_adv = tf.clip_by_value(x_adv, 0, 1)
        
        adv_preds = model(x_adv, training=False)
        adv_acc.update_state(y, adv_preds)
        
        # --- TÍNH TOÁN ATTACK SUCCESS RATE (ASR) ---
        true_labels = tf.argmax(y, axis=1)
        clean_labels = tf.argmax(clean_preds, axis=1)
        adv_labels = tf.argmax(adv_preds, axis=1)
        
        clean_correct = tf.equal(clean_labels, true_labels)
        adv_incorrect = tf.not_equal(adv_labels, true_labels)
        
        total_correct_clean += tf.reduce_sum(tf.cast(clean_correct, tf.int32)).numpy()
        successful_attacks += tf.reduce_sum(tf.cast(tf.logical_and(clean_correct, adv_incorrect), tf.int32)).numpy()
        
        # --- LƯU LẠI VÍ DỤ ĐỂ VẼ BIỂU ĐỒ ---
        if len(viz_clean_imgs) < num_visualize:
            for i in range(len(x)):
                if len(viz_clean_imgs) >= num_visualize:
                    break
                # Chỉ hiển thị những ảnh mà Tấn công thành công (Lúc đầu đoán đúng, sau bị lừa đoán sai)
                if clean_correct[i] and adv_incorrect[i]:
                    viz_clean_imgs.append(x[i].numpy())
                    viz_adv_imgs.append(x_adv[i].numpy())
                    viz_noises.append(signed_grad[i].numpy())
                    
                    viz_clean_preds.append((clean_labels[i].numpy(), np.max(clean_preds[i].numpy())))
                    viz_adv_preds.append((adv_labels[i].numpy(), np.max(adv_preds[i].numpy())))
                    viz_true_labels.append(true_labels[i].numpy())

    # --- IN KẾT QUẢ TỔNG QUAN ---
    c_acc = clean_acc.result().numpy() * 100
    a_acc = adv_acc.result().numpy() * 100
    asr = (successful_attacks / total_correct_clean * 100) if total_correct_clean > 0 else 0.0

    print("\n" + "="*50)
    print(" BÁO CÁO ĐÁNH GIÁ ĐỘ BỀN VỮNG (ROBUSTNESS REPORT)")
    print("="*50)
    print(f" Biên độ nhiễu (Epsilon)   : {epsilon}")
    print(f" 1. Standard Accuracy      : {c_acc:.2f}%  (Độ chính xác trên ảnh sạch)")
    print(f" 2. Robust Accuracy        : {a_acc:.2f}%  (Độ chính xác trên ảnh nhiễu)")
    print(f" 3. Attack Success Rate    : {asr:.2f}%  (Tỷ lệ đánh lừa mô hình thành công)")
    print("="*50)

    # --- VẼ BIỂU ĐỒ (DIAGRAMS) ---
    if len(viz_clean_imgs) > 0:
        print(f"\n Hiển thị {len(viz_clean_imgs)} ví dụ bị tấn công thành công:")
        fig = plt.figure(figsize=(12, 4 * len(viz_clean_imgs)))
        
        for i in range(len(viz_clean_imgs)):
            true_name = class_names[viz_true_labels[i]]
            
            clean_name = class_names[viz_clean_preds[i][0]]
            clean_conf = viz_clean_preds[i][1] * 100
            
            adv_name = class_names[viz_adv_preds[i][0]]
            adv_conf = viz_adv_preds[i][1] * 100
            
            # Cột 1: Ảnh gốc
            ax1 = fig.add_subplot(len(viz_clean_imgs), 3, i*3 + 1)
            ax1.imshow(viz_clean_imgs[i])
            ax1.set_title(f"Ảnh Gốc (Thực: {true_name})\nDự đoán: {clean_name} ({clean_conf:.1f}%)", color='green')
            ax1.axis('off')
            
            # Cột 2: Ma trận nhiễu
            ax2 = fig.add_subplot(len(viz_clean_imgs), 3, i*3 + 2)
            # Normalize nhiễu (-1 đến 1) về khoảng (0 đến 1) để có thể hiển thị bằng màu sắc
            noise_visual = (viz_noises[i] + 1.0) / 2.0 
            ax2.imshow(noise_visual)
            ax2.set_title(f"Bản đồ nhiễu FGSM\n(Đã phóng đại cường độ)")
            ax2.axis('off')
            
            # Cột 3: Ảnh đối kháng
            ax3 = fig.add_subplot(len(viz_clean_imgs), 3, i*3 + 3)
            ax3.imshow(viz_adv_imgs[i])
            ax3.set_title(f"Ảnh Đối Kháng (Eps={epsilon})\nDự đoán sai: {adv_name} ({adv_conf:.1f}%)", color='red')
            ax3.axis('off')
            
        plt.tight_layout()
        plt.show()
    else:
        print("\n Tuyệt vời! Không tìm thấy ví dụ nào bị tấn công thành công trong giới hạn quét.")


evaluate_robustness(
    model=model, 
    dataset=test_ds, 
    class_names=class_names, # Đã được định nghĩa ở cell dataset
    epsilon=0.01,
    num_visualize=3 # Tùy chỉnh số lượng hình vẽ 
)
# Out:
# ==================================================
#  BÁO CÁO ĐÁNH GIÁ ĐỘ BỀN VỮNG (ROBUSTNESS REPORT)
# ==================================================
#  Biên độ nhiễu (Epsilon)   : 0.01
#  1. Standard Accuracy      : 92.93%  (Độ chính xác trên ảnh sạch)
#  2. Robust Accuracy        : 77.41%  (Độ chính xác trên ảnh nhiễu)
#  3. Attack Success Rate    : 16.70%  (Tỷ lệ đánh lừa mô hình thành công)
# ==================================================
#
#  Hiển thị 3 ví dụ bị tấn công thành công:

# %% [markdown]
# ## 7. Save Model

# %%
model.save('robust_flower_model.keras')
