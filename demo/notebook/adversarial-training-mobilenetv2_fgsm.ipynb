# %% [markdown]
# # Adversarial Training for Flower Classification
#
# This notebook demonstrates how to perform **Adversarial Training** using the formula:
#
# $$\tilde{J}(\theta, x, y) = \alpha J(\theta, x, y) + (1 - \alpha) J(\theta, x + \epsilon \text{ sign}(\nabla_x J(\theta, x, y)))$$
#
# This approach makes the model more robust by training on a weighted mix of clean and adversarial examples.

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

print(f"TensorFlow version: {tf.__version__}")
# Out:
# 2026-05-09 07:58:10.338156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778313490.532860      22 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778313490.589929      22 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778313491.062827      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778313491.062876      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778313491.062879      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778313491.062881      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow version: 2.19.0

# %% [markdown]
# ## 1. Data Preparation

# %% [markdown]
# Split

# %%
DATASET_PATH = '/kaggle/input/datasets/haidangg/flowerdataset/flower_photos'
TEST_SET_PATH = '/kaggle/input/datasets/haidangg/flowerdataset/flower_photos_test'

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_SET_PATH,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)

normalization_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y))
# Out:
# Found 3090 files belonging to 5 classes.
# Using 2472 files for training.
# I0000 00:00:1778313519.243276      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1778313519.249222      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 3090 files belonging to 5 classes.
# Using 618 files for validation.
# Found 580 files belonging to 5 classes.

# %% [markdown]
# ## 2. Model Definition

# %%
URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4" 
feature_extractor_layer = hub.KerasLayer(URL, input_shape=(224, 224, 3), trainable=True) 

# Tạo mô hình tuần tự
model = models.Sequential([
    feature_extractor_layer, # Khối MobileNetV2 đã được đóng băng
    layers.Dropout(0.5), # Regularization: ngẫu nhiên loại bỏ (đặt giá trị bằng 0) 50% số lượng neuron trong lớp đó, chống Overfitting
    layers.Dense(num_classes, activation='softmax') # Khối Head nhận đặc trưng và đưa ra dự đoán, softmax đảm bảo tổng xác suất đầu ra bằng 1
])

# Biên dịch mô hình
model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## 3. Adversarial Training Wrapper
#
# Here we implement the custom training step that follows the formula.

# %%
class AdversarialModel(models.Model):
    def __init__(self, base_model, epsilon=0.01, alpha=0.5):
        super(AdversarialModel, self).__init__()
        self.base_model = base_model
        self.epsilon = epsilon
        self.alpha = alpha
        self.loss_object = tf.keras.losses.CategoricalCrossentropy()
        
        # Khởi tạo các bộ đếm Metrics chuyên biệt
        self.loss_total_metric = tf.keras.metrics.Mean(name="loss")
        self.acc_clean_metric = tf.keras.metrics.CategoricalAccuracy(name="std_acc")
        self.acc_adv_metric = tf.keras.metrics.CategoricalAccuracy(name="robust_acc")
        self.asr_metric = tf.keras.metrics.Mean(name="asr") # Attack Success Rate

    @property
    def metrics(self):
        # Keras sẽ tự động reset các thông số này khi bắt đầu một Epoch mới
        return [self.loss_total_metric, self.acc_clean_metric, self.acc_adv_metric, self.asr_metric]

    def _calculate_asr(self, y_true, pred_clean, pred_adv):
        # Hàm nội bộ tính Tỷ lệ tấn công thành công (ASR)
        true_labels = tf.argmax(y_true, axis=1)
        clean_labels = tf.argmax(pred_clean, axis=1)
        adv_labels = tf.argmax(pred_adv, axis=1)
        
        # Điều kiện 1: Ảnh sạch phải đoán ĐÚNG
        clean_correct = tf.equal(clean_labels, true_labels)
        # Điều kiện 2: Ảnh nhiễu phải đoán SAI
        adv_incorrect = tf.not_equal(adv_labels, true_labels)
        
        # Tấn công thành công = Đạt cả 2 điều kiện trên
        successful_attacks = tf.logical_and(clean_correct, adv_incorrect)
        
        num_clean_correct = tf.reduce_sum(tf.cast(clean_correct, tf.float32))
        num_successful_attacks = tf.reduce_sum(tf.cast(successful_attacks, tf.float32))
        
        # Tránh lỗi chia cho 0 nếu batch đầu tiên model đoán sai toàn bộ ảnh sạch
        asr = tf.cond(num_clean_correct > 0,
                      lambda: num_successful_attacks / num_clean_correct,
                      lambda: 0.0)
        return asr

    def train_step(self, data):
        x, y = data
        
        # 1. Chế tạo ảnh nhiễu FGSM
        with tf.GradientTape() as tape_adv:
            tape_adv.watch(x)
            prediction = self.base_model(x, training=False)
            loss_clean_for_grad = self.loss_object(y, prediction)
            
        gradient = tape_adv.gradient(loss_clean_for_grad, x)
        signed_grad = tf.sign(gradient)
        x_adv = x + self.epsilon * signed_grad
        x_adv = tf.clip_by_value(x_adv, 0, 1)
        
        # 2. Dự đoán và Tính Loss tổng
        with tf.GradientTape() as tape:
            pred_clean = self.base_model(x, training=True)
            pred_adv = self.base_model(x_adv, training=True)
            
            loss_clean = self.loss_object(y, pred_clean)
            loss_adv = self.loss_object(y, pred_adv)
            
            total_loss = self.alpha * loss_clean + (1 - self.alpha) * loss_adv
            
        # 3. Cập nhật trọng số Model
        gradients = tape.gradient(total_loss, self.base_model.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.base_model.trainable_variables))
        
        # 4. Cập nhật các thông số hiển thị
        asr = self._calculate_asr(y, pred_clean, pred_adv)
        
        self.loss_total_metric.update_state(total_loss)
        self.acc_clean_metric.update_state(y, pred_clean)
        self.acc_adv_metric.update_state(y, pred_adv)
        self.asr_metric.update_state(asr)
        
        return {m.name: m.result() for m in self.metrics}

    def test_step(self, data):
        x, y = data
        
        # 1. Chế tạo ảnh nhiễu FGSM (giống hệt train)
        with tf.GradientTape() as tape_adv:
            tape_adv.watch(x)
            prediction = self.base_model(x, training=False)
            loss_clean_for_grad = self.loss_object(y, prediction)
            
        gradient = tape_adv.gradient(loss_clean_for_grad, x)
        signed_grad = tf.sign(gradient)
        x_adv = x + self.epsilon * signed_grad
        x_adv = tf.clip_by_value(x_adv, 0, 1)
        
        # 2. Dự đoán trên tập Validation (training=False)
        pred_clean = self.base_model(x, training=False)
        pred_adv = self.base_model(x_adv, training=False)
        
        loss_clean = self.loss_object(y, pred_clean)
        loss_adv = self.loss_object(y, pred_adv)
        total_loss = self.alpha * loss_clean + (1 - self.alpha) * loss_adv
        
        # 3. Cập nhật các thông số hiển thị cho tập Validation
        asr = self._calculate_asr(y, pred_clean, pred_adv)
        
        self.loss_total_metric.update_state(total_loss)
        self.acc_clean_metric.update_state(y, pred_clean)
        self.acc_adv_metric.update_state(y, pred_adv)
        self.asr_metric.update_state(asr)
        
        return {m.name: m.result() for m in self.metrics}

    def call(self, x):
        return self.base_model(x)

# Initialize with alpha from the formula (e.g., 0.5)
adv_training_model = AdversarialModel(model, epsilon=0.01, alpha=0.5)
adv_training_model.compile(
    optimizer=Adam(learning_rate=1e-5)
)

# %% [markdown]
# ## 4. Training

# %%
# Dừng sớm nếu val_loss không giảm sau 7 epochs
early_stop = EarlyStopping(monitor='val_robust_acc', mode='max', patience=7, restore_best_weights=True)

# Giảm tốc độ học nếu mô hình bị chững lại
reduce_lr = ReduceLROnPlateau(monitor='val_robust_acc', mode='max', factor=0.5, patience=3)

EPOCHS = 100
history = adv_training_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/100
# I0000 00:00:1778313544.955862      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778313549.721826      72 service.cc:152] XLA service 0x7a8f21a28360 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778313549.721864      72 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778313549.721868      72 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1778313549.986805      72 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 78/78 [==============================] - 79s 476ms/step - loss: 2.3258 - std_acc: 0.3410 - robust_acc: 0.0631 - asr: 0.8896 - val_loss: 1.9894 - val_std_acc: 0.6327 - val_robust_acc: 0.0324 - val_asr: 0.9511 - lr: 1.0000e-05
# Epoch 2/100
# 78/78 [==============================] - 34s 436ms/step - loss: 1.8416 - std_acc: 0.5639 - robust_acc: 0.1497 - asr: 0.7789 - val_loss: 1.5439 - val_std_acc: 0.7751 - val_robust_acc: 0.1327 - val_asr: 0.8316 - lr: 1.0000e-05
# Epoch 3/100
# 78/78 [==============================] - 36s 453ms/step - loss: 1.4938 - std_acc: 0.6841 - robust_acc: 0.2439 - asr: 0.6802 - val_loss: 1.3301 - val_std_acc: 0.8252 - val_robust_acc: 0.1942 - val_asr: 0.7706 - lr: 1.0000e-05
# Epoch 4/100
# 78/78 [==============================] - 36s 459ms/step - loss: 1.3510 - std_acc: 0.7399 - robust_acc: 0.3038 - asr: 0.6162 - val_loss: 1.2257 - val_std_acc: 0.8544 - val_robust_acc: 0.2573 - val_asr: 0.7044 - lr: 1.0000e-05
# Epoch 5/100
# 78/78 [==============================] - 35s 451ms/step - loss: 1.2062 - std_acc: 0.7775 - robust_acc: 0.3447 - asr: 0.5823 - val_loss: 1.1339 - val_std_acc: 0.8706 - val_robust_acc: 0.2977 - val_asr: 0.6561 - lr: 1.0000e-05
# Epoch 6/100
# 78/78 [==============================] - 36s 455ms/step - loss: 1.1048 - std_acc: 0.8131 - robust_acc: 0.3888 - asr: 0.5308 - val_loss: 1.0855 - val_std_acc: 0.8867 - val_robust_acc: 0.3269 - val_asr: 0.6381 - lr: 1.0000e-05
# Epoch 7/100
# 78/78 [==============================] - 36s 455ms/step - loss: 1.0176 - std_acc: 0.8232 - robust_acc: 0.4244 - asr: 0.4990 - val_loss: 1.0328 - val_std_acc: 0.8916 - val_robust_acc: 0.3495 - val_asr: 0.6097 - lr: 1.0000e-05
# Epoch 8/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.9815 - std_acc: 0.8491 - robust_acc: 0.4442 - asr: 0.4887 - val_loss: 1.0133 - val_std_acc: 0.8997 - val_robust_acc: 0.3657 - val_asr: 0.6020 - lr: 1.0000e-05
# Epoch 9/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.9174 - std_acc: 0.8584 - robust_acc: 0.4672 - asr: 0.4651 - val_loss: 0.9694 - val_std_acc: 0.9013 - val_robust_acc: 0.3786 - val_asr: 0.5868 - lr: 1.0000e-05
# Epoch 10/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.8504 - std_acc: 0.8835 - robust_acc: 0.4992 - asr: 0.4470 - val_loss: 0.9253 - val_std_acc: 0.9045 - val_robust_acc: 0.3948 - val_asr: 0.5584 - lr: 1.0000e-05
# Epoch 11/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.8344 - std_acc: 0.8859 - robust_acc: 0.5049 - asr: 0.4364 - val_loss: 0.9119 - val_std_acc: 0.9061 - val_robust_acc: 0.4110 - val_asr: 0.5400 - lr: 1.0000e-05
# Epoch 12/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.7952 - std_acc: 0.8924 - robust_acc: 0.5170 - asr: 0.4254 - val_loss: 0.8858 - val_std_acc: 0.9110 - val_robust_acc: 0.4239 - val_asr: 0.5436 - lr: 1.0000e-05
# Epoch 13/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.7621 - std_acc: 0.8940 - robust_acc: 0.5356 - asr: 0.4065 - val_loss: 0.8578 - val_std_acc: 0.9175 - val_robust_acc: 0.4304 - val_asr: 0.5210 - lr: 1.0000e-05
# Epoch 14/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.7175 - std_acc: 0.9045 - robust_acc: 0.5526 - asr: 0.3973 - val_loss: 0.8386 - val_std_acc: 0.9159 - val_robust_acc: 0.4385 - val_asr: 0.5231 - lr: 1.0000e-05
# Epoch 15/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.7096 - std_acc: 0.9134 - robust_acc: 0.5514 - asr: 0.4019 - val_loss: 0.8205 - val_std_acc: 0.9239 - val_robust_acc: 0.4482 - val_asr: 0.5124 - lr: 1.0000e-05
# Epoch 16/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.6754 - std_acc: 0.9187 - robust_acc: 0.5765 - asr: 0.3812 - val_loss: 0.8069 - val_std_acc: 0.9256 - val_robust_acc: 0.4595 - val_asr: 0.5077 - lr: 1.0000e-05
# Epoch 17/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.6546 - std_acc: 0.9183 - robust_acc: 0.5971 - asr: 0.3540 - val_loss: 0.8131 - val_std_acc: 0.9272 - val_robust_acc: 0.4660 - val_asr: 0.4991 - lr: 1.0000e-05
# Epoch 18/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.6321 - std_acc: 0.9288 - robust_acc: 0.6011 - asr: 0.3528 - val_loss: 0.7886 - val_std_acc: 0.9272 - val_robust_acc: 0.4757 - val_asr: 0.4819 - lr: 1.0000e-05
# Epoch 19/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.6062 - std_acc: 0.9308 - robust_acc: 0.6121 - asr: 0.3485 - val_loss: 0.7757 - val_std_acc: 0.9288 - val_robust_acc: 0.4887 - val_asr: 0.4715 - lr: 1.0000e-05
# Epoch 20/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.6044 - std_acc: 0.9284 - robust_acc: 0.6218 - asr: 0.3355 - val_loss: 0.7776 - val_std_acc: 0.9320 - val_robust_acc: 0.4903 - val_asr: 0.4737 - lr: 1.0000e-05
# Epoch 21/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.5696 - std_acc: 0.9393 - robust_acc: 0.6379 - asr: 0.3234 - val_loss: 0.7641 - val_std_acc: 0.9304 - val_robust_acc: 0.4951 - val_asr: 0.4721 - lr: 1.0000e-05
# Epoch 22/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.5588 - std_acc: 0.9381 - robust_acc: 0.6432 - asr: 0.3180 - val_loss: 0.7600 - val_std_acc: 0.9304 - val_robust_acc: 0.4984 - val_asr: 0.4668 - lr: 1.0000e-05
# Epoch 23/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.5372 - std_acc: 0.9470 - robust_acc: 0.6549 - asr: 0.3131 - val_loss: 0.7662 - val_std_acc: 0.9320 - val_robust_acc: 0.5162 - val_asr: 0.4496 - lr: 1.0000e-05
# Epoch 24/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.5202 - std_acc: 0.9478 - robust_acc: 0.6537 - asr: 0.3132 - val_loss: 0.7453 - val_std_acc: 0.9320 - val_robust_acc: 0.5178 - val_asr: 0.4491 - lr: 1.0000e-05
# Epoch 25/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.4895 - std_acc: 0.9527 - robust_acc: 0.6824 - asr: 0.2829 - val_loss: 0.7637 - val_std_acc: 0.9320 - val_robust_acc: 0.5210 - val_asr: 0.4429 - lr: 1.0000e-05
# Epoch 26/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.4941 - std_acc: 0.9478 - robust_acc: 0.6788 - asr: 0.2852 - val_loss: 0.7414 - val_std_acc: 0.9369 - val_robust_acc: 0.5210 - val_asr: 0.4348 - lr: 1.0000e-05
# Epoch 27/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.4742 - std_acc: 0.9515 - robust_acc: 0.6913 - asr: 0.2782 - val_loss: 0.7423 - val_std_acc: 0.9353 - val_robust_acc: 0.5275 - val_asr: 0.4402 - lr: 1.0000e-05
# Epoch 28/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.4551 - std_acc: 0.9595 - robust_acc: 0.7063 - asr: 0.2655 - val_loss: 0.7312 - val_std_acc: 0.9353 - val_robust_acc: 0.5275 - val_asr: 0.4272 - lr: 1.0000e-05
# Epoch 29/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.4397 - std_acc: 0.9616 - robust_acc: 0.7075 - asr: 0.2651 - val_loss: 0.7175 - val_std_acc: 0.9353 - val_robust_acc: 0.5275 - val_asr: 0.4296 - lr: 1.0000e-05
# Epoch 30/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.4379 - std_acc: 0.9612 - robust_acc: 0.7071 - asr: 0.2647 - val_loss: 0.7070 - val_std_acc: 0.9369 - val_robust_acc: 0.5388 - val_asr: 0.4171 - lr: 1.0000e-05
# Epoch 31/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.4238 - std_acc: 0.9624 - robust_acc: 0.7225 - asr: 0.2500 - val_loss: 0.7094 - val_std_acc: 0.9353 - val_robust_acc: 0.5388 - val_asr: 0.4204 - lr: 1.0000e-05
# Epoch 32/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.4175 - std_acc: 0.9620 - robust_acc: 0.7310 - asr: 0.2427 - val_loss: 0.7338 - val_std_acc: 0.9337 - val_robust_acc: 0.5388 - val_asr: 0.4259 - lr: 1.0000e-05
# Epoch 33/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.4045 - std_acc: 0.9640 - robust_acc: 0.7358 - asr: 0.2415 - val_loss: 0.7089 - val_std_acc: 0.9353 - val_robust_acc: 0.5405 - val_asr: 0.4167 - lr: 1.0000e-05
# Epoch 34/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.3926 - std_acc: 0.9648 - robust_acc: 0.7443 - asr: 0.2310 - val_loss: 0.7199 - val_std_acc: 0.9353 - val_robust_acc: 0.5469 - val_asr: 0.4110 - lr: 1.0000e-05
# Epoch 35/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.4074 - std_acc: 0.9689 - robust_acc: 0.7358 - asr: 0.2454 - val_loss: 0.7036 - val_std_acc: 0.9369 - val_robust_acc: 0.5550 - val_asr: 0.4042 - lr: 1.0000e-05
# Epoch 36/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.3830 - std_acc: 0.9648 - robust_acc: 0.7383 - asr: 0.2368 - val_loss: 0.6958 - val_std_acc: 0.9353 - val_robust_acc: 0.5518 - val_asr: 0.4065 - lr: 1.0000e-05
# Epoch 37/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.3606 - std_acc: 0.9729 - robust_acc: 0.7613 - asr: 0.2203 - val_loss: 0.6810 - val_std_acc: 0.9353 - val_robust_acc: 0.5550 - val_asr: 0.3967 - lr: 1.0000e-05
# Epoch 38/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.3458 - std_acc: 0.9741 - robust_acc: 0.7617 - asr: 0.2213 - val_loss: 0.7291 - val_std_acc: 0.9337 - val_robust_acc: 0.5615 - val_asr: 0.3979 - lr: 1.0000e-05
# Epoch 39/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.3447 - std_acc: 0.9713 - robust_acc: 0.7759 - asr: 0.2049 - val_loss: 0.6910 - val_std_acc: 0.9304 - val_robust_acc: 0.5663 - val_asr: 0.3853 - lr: 1.0000e-05
# Epoch 40/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.3257 - std_acc: 0.9794 - robust_acc: 0.7836 - asr: 0.2007 - val_loss: 0.6927 - val_std_acc: 0.9304 - val_robust_acc: 0.5663 - val_asr: 0.3880 - lr: 1.0000e-05
# Epoch 41/100
# 78/78 [==============================] - 36s 455ms/step - loss: 0.3263 - std_acc: 0.9790 - robust_acc: 0.7763 - asr: 0.2095 - val_loss: 0.7134 - val_std_acc: 0.9337 - val_robust_acc: 0.5712 - val_asr: 0.3902 - lr: 1.0000e-05
# Epoch 42/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.3206 - std_acc: 0.9798 - robust_acc: 0.7767 - asr: 0.2094 - val_loss: 0.7151 - val_std_acc: 0.9353 - val_robust_acc: 0.5712 - val_asr: 0.3999 - lr: 1.0000e-05
# Epoch 43/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.3018 - std_acc: 0.9769 - robust_acc: 0.7994 - asr: 0.1857 - val_loss: 0.6907 - val_std_acc: 0.9337 - val_robust_acc: 0.5825 - val_asr: 0.3742 - lr: 1.0000e-05
# Epoch 44/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.2927 - std_acc: 0.9850 - robust_acc: 0.7917 - asr: 0.1993 - val_loss: 0.6967 - val_std_acc: 0.9337 - val_robust_acc: 0.5890 - val_asr: 0.3762 - lr: 1.0000e-05
# Epoch 45/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.2878 - std_acc: 0.9818 - robust_acc: 0.8054 - asr: 0.1799 - val_loss: 0.7152 - val_std_acc: 0.9337 - val_robust_acc: 0.5777 - val_asr: 0.3881 - lr: 1.0000e-05
# Epoch 46/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.2728 - std_acc: 0.9798 - robust_acc: 0.8054 - asr: 0.1809 - val_loss: 0.7171 - val_std_acc: 0.9337 - val_robust_acc: 0.5841 - val_asr: 0.3780 - lr: 1.0000e-05
# Epoch 47/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.2634 - std_acc: 0.9867 - robust_acc: 0.8099 - asr: 0.1794 - val_loss: 0.7268 - val_std_acc: 0.9353 - val_robust_acc: 0.5793 - val_asr: 0.3899 - lr: 1.0000e-05
# Epoch 48/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.2647 - std_acc: 0.9854 - robust_acc: 0.8176 - asr: 0.1751 - val_loss: 0.7312 - val_std_acc: 0.9369 - val_robust_acc: 0.5890 - val_asr: 0.3712 - lr: 5.0000e-06
# Epoch 49/100
# 78/78 [==============================] - 36s 453ms/step - loss: 0.2703 - std_acc: 0.9830 - robust_acc: 0.8200 - asr: 0.1671 - val_loss: 0.7003 - val_std_acc: 0.9353 - val_robust_acc: 0.5874 - val_asr: 0.3695 - lr: 5.0000e-06
# Epoch 50/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.2544 - std_acc: 0.9830 - robust_acc: 0.8273 - asr: 0.1576 - val_loss: 0.7153 - val_std_acc: 0.9369 - val_robust_acc: 0.5890 - val_asr: 0.3836 - lr: 5.0000e-06
# Epoch 51/100
# 78/78 [==============================] - 36s 454ms/step - loss: 0.2521 - std_acc: 0.9858 - robust_acc: 0.8273 - asr: 0.1617 - val_loss: 0.7145 - val_std_acc: 0.9353 - val_robust_acc: 0.5809 - val_asr: 0.3802 - lr: 2.5000e-06

# %% [markdown]
# ## 5. Training Monitoring

# %%
def plot_training_history(history):
    # Lấy dictionary chứa lịch sử các thông số
    h = history.history
    
    # Lấy số lượng epoch thực tế (đề phòng EarlyStopping dừng sớm)
    epochs = range(1, len(h['loss']) + 1)
    
    # Tạo một khung hình lớn chứa 4 biểu đồ nhỏ (2 hàng, 2 cột)
    plt.figure(figsize=(16, 10))
    plt.suptitle('BÁO CÁO QUÁ TRÌNH HUẤN LUYỆN ĐỐI KHÁNG', fontsize=16, fontweight='bold', y=1.02)

    # ---------------------------------------------
    # BIỂU ĐỒ 1: TỔNG SAI SỐ (TOTAL LOSS) - CÀNG THẤP CÀNG TỐT
    # ---------------------------------------------
    plt.subplot(2, 2, 1)
    plt.plot(epochs, h['loss'], 'b-', linewidth=2, label='Train Loss')
    if 'val_loss' in h:
        plt.plot(epochs, h['val_loss'], 'r--', linewidth=2, label='Validation Loss')
    plt.title('1. Biến thiên Tổng Sai Số (Loss)')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()

    # ---------------------------------------------
    # BIỂU ĐỒ 2: STANDARD ACCURACY - CÀNG CAO CÀNG TỐT
    # ---------------------------------------------
    plt.subplot(2, 2, 2)
    plt.plot(epochs, h['std_acc'], 'b-', linewidth=2, label='Train Std Acc')
    if 'val_std_acc' in h:
        plt.plot(epochs, h['val_std_acc'], 'r--', linewidth=2, label='Validation Std Acc')
    plt.title('2. Độ chính xác trên Ảnh Sạch (Standard Acc)')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1.05])
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()

    # ---------------------------------------------
    # BIỂU ĐỒ 3: ROBUST ACCURACY - CÀNG CAO CÀNG TỐT
    # ---------------------------------------------
    plt.subplot(2, 2, 3)
    plt.plot(epochs, h['robust_acc'], 'b-', linewidth=2, label='Train Robust Acc')
    if 'val_robust_acc' in h:
        plt.plot(epochs, h['val_robust_acc'], 'r--', linewidth=2, label='Validation Robust Acc')
    plt.title('3. Sức đề kháng với Ảnh Nhiễu (Robust Acc)')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1.05])
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()

    # ---------------------------------------------
    # BIỂU ĐỒ 4: ATTACK SUCCESS RATE (ASR) - CÀNG THẤP CÀNG TỐT
    # ---------------------------------------------
    plt.subplot(2, 2, 4)
    plt.plot(epochs, h['asr'], 'b-', linewidth=2, label='Train ASR')
    if 'val_asr' in h:
        plt.plot(epochs, h['val_asr'], 'r--', linewidth=2, label='Validation ASR')
    plt.title('4. Tỷ lệ Bị Đánh Lừa Thành Công (ASR)')
    plt.xlabel('Epochs')
    plt.ylabel('Attack Success Rate')
    plt.ylim([-0.05, 1.05])
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()

    # Tối ưu khoảng cách giữa các biểu đồ
    plt.tight_layout()
    plt.show()

# Gọi hàm vẽ bằng cách truyền biến history vào
plot_training_history(history)

# %% [markdown]
# ## 6. Evaluation

# %%
def evaluate_robustness(model, dataset, class_names, epsilon=0.01, num_visualize=3):
    """
    Hàm đánh giá độ bền vững của mô hình và trực quan hóa kết quả.
    
    Args:
        model: Mô hình Keras cần đánh giá.
        dataset: Tập dữ liệu (VD: val_ds).
        class_names: Danh sách tên các nhãn (VD: ['Hoa cúc', 'Hoa hồng', ...]).
        epsilon: Biên độ nhiễu.
        num_visualize: Số lượng ví dụ muốn hiển thị ra biểu đồ.
    """
    clean_acc = tf.keras.metrics.CategoricalAccuracy()
    adv_acc = tf.keras.metrics.CategoricalAccuracy()
    
    total_correct_clean = 0
    successful_attacks = 0
    
    # Biến lưu trữ dữ liệu để vẽ biểu đồ
    viz_clean_imgs, viz_adv_imgs, viz_noises = [], [], []
    viz_clean_preds, viz_adv_preds, viz_true_labels = [], [], []

    for x, y in dataset:
        # Nhớ để training=False để Dropout/BatchNorm không hoạt động sai
        clean_preds = model(x, training=False) 
        clean_acc.update_state(y, clean_preds)
        
        with tf.GradientTape() as tape:
            tape.watch(x)
            preds = model(x, training=False)
            loss = tf.keras.losses.CategoricalCrossentropy()(y, preds)
        
        grad = tape.gradient(loss, x)
        signed_grad = tf.sign(grad)
        x_adv = x + epsilon * signed_grad
        x_adv = tf.clip_by_value(x_adv, 0, 1)
        
        adv_preds = model(x_adv, training=False)
        adv_acc.update_state(y, adv_preds)
        
        # --- TÍNH TOÁN ATTACK SUCCESS RATE (ASR) ---
        true_labels = tf.argmax(y, axis=1)
        clean_labels = tf.argmax(clean_preds, axis=1)
        adv_labels = tf.argmax(adv_preds, axis=1)
        
        clean_correct = tf.equal(clean_labels, true_labels)
        adv_incorrect = tf.not_equal(adv_labels, true_labels)
        
        total_correct_clean += tf.reduce_sum(tf.cast(clean_correct, tf.int32)).numpy()
        successful_attacks += tf.reduce_sum(tf.cast(tf.logical_and(clean_correct, adv_incorrect), tf.int32)).numpy()
        
        # --- LƯU LẠI VÍ DỤ ĐỂ VẼ BIỂU ĐỒ ---
        if len(viz_clean_imgs) < num_visualize:
            for i in range(len(x)):
                if len(viz_clean_imgs) >= num_visualize:
                    break
                # Chỉ hiển thị những ảnh mà Tấn công thành công (Lúc đầu đoán đúng, sau bị lừa đoán sai)
                if clean_correct[i] and adv_incorrect[i]:
                    viz_clean_imgs.append(x[i].numpy())
                    viz_adv_imgs.append(x_adv[i].numpy())
                    viz_noises.append(signed_grad[i].numpy())
                    
                    viz_clean_preds.append((clean_labels[i].numpy(), np.max(clean_preds[i].numpy())))
                    viz_adv_preds.append((adv_labels[i].numpy(), np.max(adv_preds[i].numpy())))
                    viz_true_labels.append(true_labels[i].numpy())

    # --- IN KẾT QUẢ TỔNG QUAN ---
    c_acc = clean_acc.result().numpy() * 100
    a_acc = adv_acc.result().numpy() * 100
    asr = (successful_attacks / total_correct_clean * 100) if total_correct_clean > 0 else 0.0

    print("\n" + "="*50)
    print(" BÁO CÁO ĐÁNH GIÁ ĐỘ BỀN VỮNG (ROBUSTNESS REPORT)")
    print("="*50)
    print(f" Biên độ nhiễu (Epsilon)   : {epsilon}")
    print(f" 1. Standard Accuracy      : {c_acc:.2f}%  (Độ chính xác trên ảnh sạch)")
    print(f" 2. Robust Accuracy        : {a_acc:.2f}%  (Độ chính xác trên ảnh nhiễu)")
    print(f" 3. Attack Success Rate    : {asr:.2f}%  (Tỷ lệ đánh lừa mô hình thành công)")
    print("="*50)

    # --- VẼ BIỂU ĐỒ (DIAGRAMS) ---
    if len(viz_clean_imgs) > 0:
        print(f"\n Hiển thị {len(viz_clean_imgs)} ví dụ bị tấn công thành công:")
        fig = plt.figure(figsize=(12, 4 * len(viz_clean_imgs)))
        
        for i in range(len(viz_clean_imgs)):
            true_name = class_names[viz_true_labels[i]]
            
            clean_name = class_names[viz_clean_preds[i][0]]
            clean_conf = viz_clean_preds[i][1] * 100
            
            adv_name = class_names[viz_adv_preds[i][0]]
            adv_conf = viz_adv_preds[i][1] * 100
            
            # Cột 1: Ảnh gốc
            ax1 = fig.add_subplot(len(viz_clean_imgs), 3, i*3 + 1)
            ax1.imshow(viz_clean_imgs[i])
            ax1.set_title(f"Ảnh Gốc (Thực: {true_name})\nDự đoán: {clean_name} ({clean_conf:.1f}%)", color='green')
            ax1.axis('off')
            
            # Cột 2: Ma trận nhiễu
            ax2 = fig.add_subplot(len(viz_clean_imgs), 3, i*3 + 2)
            # Normalize nhiễu (-1 đến 1) về khoảng (0 đến 1) để có thể hiển thị bằng màu sắc
            noise_visual = (viz_noises[i] + 1.0) / 2.0 
            ax2.imshow(noise_visual)
            ax2.set_title(f"Bản đồ nhiễu FGSM\n(Đã phóng đại cường độ)")
            ax2.axis('off')
            
            # Cột 3: Ảnh đối kháng
            ax3 = fig.add_subplot(len(viz_clean_imgs), 3, i*3 + 3)
            ax3.imshow(viz_adv_imgs[i])
            ax3.set_title(f"Ảnh Đối Kháng (Eps={epsilon})\nDự đoán sai: {adv_name} ({adv_conf:.1f}%)", color='red')
            ax3.axis('off')
            
        plt.tight_layout()
        plt.show()
    else:
        print("\n Tuyệt vời! Không tìm thấy ví dụ nào bị tấn công thành công trong giới hạn quét.")


evaluate_robustness(
    model=model, 
    dataset=test_ds, 
    class_names=class_names, # Đã được định nghĩa ở cell dataset
    epsilon=0.01,
    num_visualize=3 # Tùy chỉnh số lượng hình vẽ 
)
# Out:
# ==================================================
#  BÁO CÁO ĐÁNH GIÁ ĐỘ BỀN VỮNG (ROBUSTNESS REPORT)
# ==================================================
#  Biên độ nhiễu (Epsilon)   : 0.01
#  1. Standard Accuracy      : 92.93%  (Độ chính xác trên ảnh sạch)
#  2. Robust Accuracy        : 59.48%  (Độ chính xác trên ảnh nhiễu)
#  3. Attack Success Rate    : 35.99%  (Tỷ lệ đánh lừa mô hình thành công)
# ==================================================
#
#  Hiển thị 3 ví dụ bị tấn công thành công:

# %% [markdown]
# ## 7. Save Model

# %%
model.save('robust_flower_model.keras')
